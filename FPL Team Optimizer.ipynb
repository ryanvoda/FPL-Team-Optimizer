# %%
import pulp
import numpy as np
import pandas as pd
import requests
import bs4
import urllib.request
from bs4 import BeautifulSoup
from urllib.request import urlopen
from pprint import pprint

def select_team(expected_scores, prices, positions, teams, total_budget=100, sub_factor=0.1):
    num_players = len(expected_scores)
    model = pulp.LpProblem("Constrained value maximisation", pulp.LpMaximize)
    decisions = [
        pulp.LpVariable("x{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ]
    captain_decisions = [
        pulp.LpVariable("y{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ]
    sub_decisions = [
        pulp.LpVariable("z{}".format(i), lowBound=0, upBound=1, cat='Integer')
        for i in range(num_players)
    ]


    # objective function:
    model += sum((captain_decisions[i] + decisions[i] + sub_decisions[i]*sub_factor) * expected_scores[i]
                 for i in range(num_players)), "Objective"

    # cost constraint
    model += sum((decisions[i] + sub_decisions[i]) * prices[i] for i in range(num_players)) <= total_budget  # total cost

    # position constraints
    # 1 starting goalkeeper
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 'GK') == 1
    # 2 total goalkeepers
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 'GK') == 2

    # 3-5 starting defenders
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 'DEF') >= 3
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 'DEF') <= 5
    # 5 total defenders
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 'DEF') == 5

    # 3-5 starting midfielders
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 'MID') >= 3
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 'MID') <= 5
    # 5 total midfielders
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 'MID') == 5

    # 1-3 starting attackers
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 'FWD') >= 1
    model += sum(decisions[i] for i in range(num_players) if positions[i] == 'FWD') <= 3
    # 3 total attackers
    model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if positions[i] == 'FWD') == 3

    # team constraint
    for team_name in np.unique(teams):
        model += sum(decisions[i] + sub_decisions[i] for i in range(num_players) if teams[i] == team_name) <= 3  # max 3 players

    model += sum(decisions) == 11  # total team size
    model += sum(captain_decisions) == 1  # 1 captain
    
    for i in range(num_players):  
        model += (decisions[i] - captain_decisions[i]) >= 0  # captain must also be on team
        model += (decisions[i] + sub_decisions[i]) <= 1  # subs must not be on team

    model.solve()
    print("Total expected score = {}".format(model.objective.value()))

    return decisions, captain_decisions, sub_decisions

# %%
url = 'https://fplform.com/fpl-predicted-points'
r = requests.get(url)
print(r.status_code) # hopefully it's 200, so we got something
soup = BeautifulSoup(r.text, 'html.parser')
# Out:
# 200

# %%
player_data = pd.read_html(url)
player_data[0]
# Out:
#      ✔Click to move selected players to the top            Player  \
# 0                                           NaN               Son
# 1                                           NaN             Salah
# 2                                           NaN              Kane
# 3                                           NaN           Perišić
# 4                                           NaN  Alexander-Arnold
# ..                                          ...               ...
# 554                                         NaN            Rondón
# 555                                         NaN          Hendrick
# 556                                         NaN           Roberts
# 557                                         NaN       André Gomes
# 558                                         0.0   PlayersSelected
#
#     forInfoClick for player info popup                       Team  \
# 0                                  NaN                        TOT
# 1                                  NaN                        LIV
# 2                                  NaN                        TOT
# 3                                  NaN                        TOT
# 4                                  NaN                        LIV
# ..                                 ...                        ...
# 554                                NaN                        EVE
# 555                                NaN                        NEW
# 556                                NaN                        BHA
# 557                                NaN                        EVE
# 558                            forInfo  Totals forselectedplayers
#
#                    PosPosition  CostPlayer's current price  \
# 0                          MID                        12.0
# 1                          MID                        13.0
# 2                          FWD                        11.5
# 3                          DEF                         5.5
# 4                          DEF                         7.5
# ..                         ...                         ...
# 554                        FWD                         5.0
# 555                        MID                         4.5
# 556                        DEF                         4.0
# 557                        MID                         4.5
# 558  Totals forselectedplayers                         0.0
#
#     MeritHow good the player is in terms of likelihood to score FPL points  \
# 0                                                 6.61
# 1                                                 6.74
# 2                                                    6
# 3                                                  4.5
# 4                                                 5.87
# ..                                                 ...
# 554                                               1.45
# 555                                                1.7
# 556                                               1.57
# 557                                               1.16
# 558                                              Merit
#
#     FormOver/under-performance over the last 4 gameweeks compared to predicted points  \
# 0                                                 1.43
# 1                                                 0.91
# 2                                                 1.43
# 3                                                 0.37
# 4                                                 0.67
# ..                                                 ...
# 554                                               0.59
# 555                                                  1
# 556                                                  1
# 557                                               0.96
# 558                                               Form
#
#     Prob. ofAppear-ingProbability that the player will play at all in the next match  \
# 0                                                 0.97
# 1                                                 0.97
# 2                                                 0.97
# 3                                                 0.67
# 4                                                 0.81
# ..                                                 ...
# 554                                                  0
# 555                                                  0
# 556                                                  0
# 557                                                  0
# 558                                 Prob. ofAppear-ing
#
#      PPGW1  ... ValNext6  \
# 0      6.3  ...     4.11
# 1      6.1  ...     3.77
# 2      6.0  ...     3.73
# 3      5.9  ...    11.05
# 4      5.7  ...      8.5
# ..     ...  ...      ...
# 554    0.0  ...     5.04
# 555    0.0  ...        0
# 556    0.0  ...        0
# 557    0.0  ...      5.7
# 558    0.0  ...      GW6
#
#      PPRest OfSeasonPredicted FPL points for the rest of the season  \
# 0                                                  214
# 1                                                  219
# 2                                                  177
# 3                                                  166
# 4                                                  214
# ..                                                 ...
# 554                                                 55
# 555                                                  0
# 556                                                  0
# 557                                                 50
# 558                                                  0
#
#      ValueRest OfSeasonPlayer's value for the rest of the season (predicted points per million pounds excess cost)  \
# 0                                                 25.2
# 1                                                 23.1
# 2                                                 22.1
# 3                                                 66.3
# 4                                                 47.5
# ..                                                 ...
# 554                                                 37
# 555                                                  0
# 556                                                  0
# 557                                               50.4
# 558                                      Rest OfSeason
#
#      PointsSo Far  \
# 0             258
# 1             265
# 2             192
# 3               0
# 4             208
# ..            ...
# 554            30
# 555             8
# 556             0
# 557            18
# 558  PointsSo Far
#
#      OfficialChancePlayer's official chance of playing the next match  \
# 0                                                  100
# 1                                                  100
# 2                                                  100
# 3                                                  100
# 4                                                  100
# ..                                                 ...
# 554                                                  0
# 555                                                  0
# 556                                                  0
# 557                                                  0
# 558                                     OfficialChance
#
#      OfficialAvailability  \
# 0               Available
# 1               Available
# 2               Available
# 3               Available
# 4               Available
# ..                    ...
# 554             Suspended
# 555           Unavailable
# 556           Unavailable
# 557               Injured
# 558  OfficialAvailability
#
#     SelectedBy %Percentage of managers owning this player  \
# 0                                                 25.2
# 1                                                 61.0
# 2                                                 27.7
# 3                                                 28.0
# 4                                                 59.0
# ..                                                 ...
# 554                                                0.2
# 555                                                0.0
# 556                                                0.0
# 557                                                0.4
# 558                                       SelectedBy %
#
#      TransfersIn GWNumber of transfers in since the last transfer deadline  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 554                                                  0
# 555                                                  0
# 556                                                  0
# 557                                                  0
# 558                                     TransfersIn GW
#
#      TransfersOut GWNumber of transfers out since the last transfer deadline  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 554                                                  0
# 555                                                  0
# 556                                                  0
# 557                                                  0
# 558                                    TransfersOut GW
#
#                                                   News
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 554                             Suspended until 13 Aug
# 555      Joined Reading on loan - Expected back 01 Jul
# 556  Joined Derby County on loan - Expected back 01...
# 557               Muscle injury - Expected back 20 Aug
# 558                                               News
#
# [559 rows x 35 columns]

# %%
players = player_data[0].loc[:,"Player"]
teams = player_data[0].loc[:,"Team"]
positions = player_data[0].loc[:,"PosPosition"]
prices = player_data[0].loc[:,"CostPlayer's current price"]
ppnext6 = player_data[0].loc[:,"PPNext6"]
ppall = player_data[0].loc[:,"PPRest OfSeasonPredicted FPL points for the rest of the season"]

# %%
# The last values of our arrays of data picked up some ugly parts of the site we scraped:

# %%
ppnext6.values
ppall.values
prices.values
positions.values
players.values
teams.values
# Out:
# array(['TOT', 'LIV', 'TOT', 'TOT', 'LIV', 'LIV', 'TOT', 'TOT', 'LIV',
#        'NEW', 'TOT', 'LIV', 'TOT', 'CHE', 'TOT', 'MCI', 'CHE', 'TOT',
#        'NEW', 'TOT', 'TOT', 'TOT', 'LIV', 'LEI', 'CHE', 'LIV', 'CHE',
#        'NEW', 'CHE', 'LEE', 'AVL', 'AVL', 'TOT', 'NEW', 'MUN', 'NEW',
#        'MCI', 'MCI', 'MCI', 'MUN', 'NEW', 'WOL', 'CHE', 'CRY', 'LIV',
#        'LIV', 'CRY', 'AVL', 'NEW', 'LEI', 'MCI', 'BHA', 'CRY', 'NEW',
#        'WOL', 'TOT', 'NEW', 'CHE', 'MCI', 'CHE', 'NEW', 'ARS', 'CRY',
#        'AVL', 'LEI', 'TOT', 'MUN', 'ARS', 'AVL', 'NEW', 'BHA', 'WOL',
#        'CRY', 'BOU', 'TOT', 'AVL', 'WOL', 'LEI', 'LEI', 'WOL', 'MCI',
#        'WOL', 'WOL', 'LEE', 'WHU', 'AVL', 'ARS', 'CRY', 'MUN', 'LEE',
#        'ARS', 'WHU', 'ARS', 'CHE', 'SOU', 'BOU', 'WOL', 'TOT', 'AVL',
#        'BRE', 'MUN', 'ARS', 'LEE', 'WOL', 'MCI', 'TOT', 'ARS', 'LEI',
#        'LIV', 'TOT', 'CHE', 'BRE', 'LIV', 'AVL', 'CRY', 'ARS', 'BHA',
#        'CHE', 'LEE', 'CHE', 'MCI', 'LIV', 'BHA', 'BHA', 'NFO', 'AVL',
#        'AVL', 'WOL', 'LEI', 'LEI', 'CHE', 'NEW', 'CRY', 'LEI', 'BHA',
#        'BHA', 'ARS', 'BRE', 'ARS', 'LEE', 'NEW', 'CHE', 'BRE', 'AVL',
#        'MCI', 'ARS', 'CHE', 'BRE', 'AVL', 'LIV', 'MCI', 'NEW', 'BHA',
#        'NEW', 'TOT', 'LIV', 'ARS', 'BRE', 'LIV', 'CHE', 'MCI', 'CHE',
#        'SOU', 'WOL', 'LEI', 'AVL', 'EVE', 'MUN', 'NEW', 'CRY', 'MUN',
#        'LEE', 'WOL', 'NEW', 'CRY', 'LEI', 'WOL', 'WOL', 'AVL', 'WOL',
#        'FUL', 'CHE', 'AVL', 'BRE', 'LEI', 'CRY', 'BOU', 'BOU', 'BOU',
#        'BOU', 'BOU', 'BOU', 'BRE', 'MCI', 'TOT', 'FUL', 'MUN', 'MUN',
#        'CRY', 'CRY', 'NEW', 'MUN', 'CRY', 'CHE', 'NEW', 'BHA', 'NFO',
#        'WHU', 'BHA', 'CHE', 'AVL', 'SOU', 'AVL', 'WOL', 'MUN', 'BRE',
#        'MUN', 'BOU', 'BOU', 'BOU', 'BOU', 'BOU', 'AVL', 'NEW', 'BRE',
#        'NFO', 'NFO', 'LEI', 'MUN', 'MCI', 'NEW', 'MUN', 'ARS', 'WHU',
#        'LEI', 'WOL', 'WOL', 'ARS', 'BRE', 'ARS', 'FUL', 'LIV', 'NFO',
#        'NFO', 'NFO', 'NFO', 'NFO', 'NFO', 'NFO', 'NFO', 'CHE', 'LEI',
#        'LIV', 'SOU', 'ARS', 'FUL', 'WOL', 'LEI', 'LIV', 'FUL', 'AVL',
#        'EVE', 'NEW', 'LEI', 'LEI', 'MUN', 'SOU', 'NEW', 'LIV', 'WHU',
#        'BHA', 'MCI', 'WHU', 'TOT', 'MUN', 'LEE', 'FUL', 'FUL', 'CHE',
#        'SOU', 'LEI', 'ARS', 'LEE', 'LEE', 'SOU', 'BRE', 'MUN', 'CHE',
#        'LEI', 'CRY', 'BHA', 'WHU', 'BHA', 'BHA', 'BRE', 'SOU', 'MCI',
#        'CRY', 'EVE', 'LEI', 'EVE', 'EVE', 'WHU', 'NEW', 'LIV', 'SOU',
#        'MUN', 'BHA', 'CRY', 'BHA', 'BHA', 'SOU', 'NFO', 'NFO', 'NFO',
#        'NFO', 'EVE', 'EVE', 'EVE', 'CHE', 'MUN', 'MUN', 'EVE', 'LEE',
#        'NEW', 'MUN', 'BOU', 'BOU', 'BOU', 'BOU', 'BOU', 'BOU', 'LIV',
#        'ARS', 'SOU', 'WHU', 'SOU', 'CHE', 'LEE', 'AVL', 'SOU', 'BHA',
#        'EVE', 'SOU', 'LIV', 'CHE', 'LEI', 'LEE', 'NEW', 'ARS', 'ARS',
#        'EVE', 'CHE', 'ARS', 'WHU', 'EVE', 'MCI', 'LEE', 'CRY', 'EVE',
#        'WOL', 'LEI', 'AVL', 'FUL', 'BRE', 'FUL', 'FUL', 'FUL', 'FUL',
#        'ARS', 'LEI', 'BHA', 'CHE', 'BOU', 'NFO', 'MUN', 'WHU', 'CRY',
#        'TOT', 'EVE', 'TOT', 'TOT', 'LEI', 'FUL', 'SOU', 'LIV', 'FUL',
#        'AVL', 'SOU', 'NEW', 'MCI', 'EVE', 'WOL', 'ARS', 'LIV', 'LIV',
#        'NFO', 'BRE', 'TOT', 'TOT', 'MUN', 'CRY', 'SOU', 'MUN', 'MUN',
#        'LEE', 'SOU', 'BHA', 'BHA', 'BHA', 'BHA', 'CRY', 'AVL', 'WHU',
#        'WHU', 'BHA', 'BOU', 'NFO', 'NFO', 'NFO', 'NFO', 'NFO', 'WOL',
#        'BRE', 'WHU', 'ARS', 'AVL', 'NFO', 'BOU', 'FUL', 'FUL', 'FUL',
#        'FUL', 'FUL', 'FUL', 'ARS', 'LEE', 'LEE', 'CRY', 'MUN', 'ARS',
#        'BRE', 'AVL', 'CRY', 'MCI', 'ARS', 'EVE', 'BRE', 'LEI', 'WHU',
#        'LEE', 'AVL', 'FUL', 'FUL', 'FUL', 'FUL', 'BHA', 'SOU', 'BRE',
#        'EVE', 'SOU', 'EVE', 'AVL', 'BRE', 'NFO', 'CRY', 'SOU', 'WHU',
#        'MCI', 'MCI', 'EVE', 'BRE', 'SOU', 'WHU', 'WHU', 'BRE', 'WHU',
#        'FUL', 'LEE', 'SOU', 'WHU', 'SOU', 'EVE', 'AVL', 'BHA', 'AVL',
#        'FUL', 'MCI', 'WHU', 'LIV', 'EVE', 'BRE', 'LEE', 'LEE', 'LIV',
#        'BOU', 'EVE', 'AVL', 'LEE', 'WHU', 'TOT', 'CRY', 'NFO', 'BRE',
#        'ARS', 'NFO', 'TOT', 'SOU', 'NFO', 'MCI', 'WOL', 'BHA', 'LEI',
#        'LEE', 'LIV', 'EVE', 'BRE', 'TOT', 'SOU', 'MUN', 'SOU', 'LEE',
#        'LEI', 'NEW', 'LEE', 'CRY', 'BRE', 'LEE', 'CRY', 'TOT', 'BHA',
#        'CRY', 'EVE', 'SOU', 'WHU', 'TOT', 'LEE', 'MCI', 'LEE', 'NFO',
#        'TOT', 'BOU', 'WOL', 'BRE', 'NEW', 'NFO', 'LIV', 'LEE', 'LEE',
#        'NFO', 'BRE', 'BRE', 'WOL', 'MCI', 'EVE', 'NEW', 'BHA', 'EVE',
#        'Totals forselectedplayers'], dtype=object)

# %%
chopped_ppnext6 = ppnext6.values[0:-1]
chopped_prices = prices.values[0:-1]
chopped_positions = positions.values[0:-1]
chopped_players = players.values[0:-1]
chopped_teams = teams.values[0:-1]
chopped_ppall = ppall.values[0:-1]

best_ppnext6 = pd.Series(chopped_ppnext6)
best_prices = pd.Series(chopped_prices)
best_positions = pd.Series(chopped_positions)
best_players = pd.Series(chopped_players)
best_teams = pd.Series(chopped_teams)
best_ppall = pd.Series(chopped_ppall)

best_teams
# Out:
# 0      TOT
# 1      LIV
# 2      TOT
# 3      TOT
# 4      LIV
#       ...
# 553    MCI
# 554    EVE
# 555    NEW
# 556    BHA
# 557    EVE
# Length: 558, dtype: object

# %%
# Team made for the close future (next 6 gameweeks):

decisions, captain_decisions, sub_decisions = select_team(best_ppnext6, best_prices, best_positions, best_teams)
player_indices = []

print()
print("First Team:")
for i in range(len(decisions)):
    if decisions[i].value() == 1:
        print("{}{}".format(best_players[i], "*" if captain_decisions[i].value() == 1 else ""))
        player_indices.append(i)
print()
print("Subs:")
for i in range(len(sub_decisions)):
    if sub_decisions[i].value() == 1:
        print(best_players[i])
        player_indices.append(i)
# Out:
# C:\Users\ryvo1\anaconda3\envs\PIC16B\lib\site-packages\pulp\pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Total expected score = 371.33
#
# First Team:
# Son
# Kane
# Perišić
# Alexander-Arnold*
# Robertson
# Matip
# Pope
# Foden
# Cancelo
# Trossard
# Ward-Prowse
#
# Subs:
# Iversen
# Amad
# Dervişoğlu
# Taylor

# %%
# Team made for the entire season (set and forget, no transfers):

decisions, captain_decisions, sub_decisions = select_team(best_ppall, best_prices, best_positions, best_teams)
player_indices = []

print()
print("First Team:")
for i in range(len(decisions)):
    if decisions[i].value() == 1:
        print("{}{}".format(best_players[i], "*" if captain_decisions[i].value() == 1 else ""))
        player_indices.append(i)
print()
print("Subs:")
for i in range(len(sub_decisions)):
    if sub_decisions[i].value() == 1:
        print(best_players[i])
        player_indices.append(i)
# Out:
# Total expected score = 2197.0
#
# First Team:
# Son*
# Perišić
# Alexander-Arnold
# Robertson
# Sterling
# Koulibaly
# Alisson
# Foden
# Cancelo
# Gündogan
# Toney
#
# Subs:
# Iversen
# Amad
# Dervişoğlu
# Plange
